# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np
import random
import os
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import xgboost
import catboost


from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Descriptors
from rdkit import RDConfig
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from rdkit.Chem import PandasTools as PandasTools
from rdkit import DataStructs
from rdkit.Chem.Subshape import SubshapeBuilder,SubshapeAligner,SubshapeObjects

# %%
def pIC50_to_IC50(pic50_values):
    """Convert pIC50 values to IC50 (nM)."""
    return 10 ** (9 - pic50_values)

# %% [markdown]
# ### DataLoad

# %%
# 학습 ChEMBL 데이터 로드
df = pd.read_csv('train.csv')  # 예시 파일 이름
df.head()
# Out:
#   Molecule ChEMBL ID Standard Type Standard Relation  Standard Value  \
# 0      CHEMBL4443947          IC50               '='           0.022
# 1      CHEMBL4556091          IC50               '='           0.026
# 2      CHEMBL4566431          IC50               '='           0.078
# 3      CHEMBL4545898          IC50               '='           0.081
# 4      CHEMBL4448950          IC50               '='           0.099
#
#   Standard Units  pChEMBL Value Assay ChEMBL ID Target ChEMBL ID  \
# 0             nM          10.66   CHEMBL4361896       CHEMBL3778
# 1             nM          10.59   CHEMBL4345131       CHEMBL3778
# 2             nM          10.11   CHEMBL4345131       CHEMBL3778
# 3             nM          10.09   CHEMBL4345131       CHEMBL3778
# 4             nM          10.00   CHEMBL4361896       CHEMBL3778
#
#                                   Target Name Target Organism     Target Type  \
# 0  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 1  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 2  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 3  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 4  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
#
#   Document ChEMBL ID  IC50_nM  pIC50  \
# 0      CHEMBL4359855    0.022  10.66
# 1      CHEMBL4342485    0.026  10.59
# 2      CHEMBL4342485    0.078  10.11
# 3      CHEMBL4342485    0.081  10.09
# 4      CHEMBL4359855    0.099  10.00
#
#                                               Smiles
# 0  CN[C@@H](C)C(=O)N[C@H](C(=O)N1C[C@@H](NC(=O)CC...
# 1  CC(C)(O)[C@H](F)CN1Cc2cc(NC(=O)c3cnn4cccnc34)c...
# 2  CC(C)(O)[C@H](F)CN1Cc2cc(NC(=O)c3cnn4cccnc34)c...
# 3  CC(C)(O)[C@H](F)CN1Cc2cc(NC(=O)c3cnn4cccnc34)c...
# 4  COc1cc2c(OC[C@@H]3CCC(=O)N3)ncc(C#CCCCCCCCCCCC...

# %% [markdown]
# ### Data Pre-processing

# %%
#제거 변수

delete = ['Molecule ChEMBL ID','Standard Type','Standard Relation','Standard Value','Standard Units','pChEMBL Value','Assay ChEMBL ID','Target ChEMBL ID','Target Name','Target Organism',
          'Target Type','Document ChEMBL ID','pIC50','IC50_nM']

# %%
y_train = df['pIC50'].values
x_train = df.drop(delete ,axis=1)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %% [markdown]
# ### Train & Validation

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train,y_train, test_size=0.3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense,Input,Dropout,LSTM, Conv1D, Bidirectional, LSTM, GRU, RNN, MaxPool1D, Flatten,Embedding
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.backend import clear_session
import re

# %%
REGEXPS = {
        "brackets": re.compile(r"(\[[^\]]*\])"),
        "2_ring_nums": re.compile(r"(%\d{2})"),
        "brcl": re.compile(r"(Br|Cl)")
    }
REGEXP_ORDER = ["brackets", "2_ring_nums", "brcl"]

def tokenize(data, with_begin_and_end=True):
    """Tokenizes a SMILES string."""
    def split_by(data, regexps):
        if not regexps:
            return list(data)
        regexp = REGEXPS[regexps[0]]
        splitted = regexp.split(data)
        tokens = []
        for i, split in enumerate(splitted):
            if i % 2 == 0:
                tokens += split_by(split, regexps[1:])
            else:
                tokens.append(split)
        return tokens

    tokens = split_by(data, REGEXP_ORDER)
    
    # if true, the token set is enriched by "^" and "$" denoting the start and end of the embedding, respectively
    if with_begin_and_end:
        tokens = ["^"] + tokens + ["$"]
    return tokens

# %%
x_train['Smiles'] = x_train['Smiles'].apply(tokenize)
x_val['Smiles'] = x_val['Smiles'].apply(tokenize)

# %%
# x_train과 x_val이 이미 정의되어 있다고 가정합니다.
x_train = x_train['Smiles'].tolist()
x_val = x_val['Smiles'].tolist()

# Tokenize the SMILES strings
tokenizer = Tokenizer(char_level=True, filters='')
tokenizer.fit_on_texts(x_train)

# 어휘 사전의 크기 확인
vocab_size = len(tokenizer.word_index) + 1  # +1은 0을 포함시키기 위한 것
print("Vocabulary size:", vocab_size)

# 텍스트를 시퀀스로 변환
train_sequences = tokenizer.texts_to_sequences(x_train)
val_sequences = tokenizer.texts_to_sequences(x_val)

# Padding sequences to have the same length (adjust maxlen as necessary)
maxlen = 20  # This should be set according to your data
x_train_padded = pad_sequences(train_sequences, maxlen=maxlen, padding='post')
x_val_padded = pad_sequences(val_sequences, maxlen=maxlen, padding='post')
# Out:
# Vocabulary size: 36

# %%
embedding_dim = 35
max_words = 100

# %%
print("Character counts in the training data:")
print(tokenizer.word_counts)
print("Unique characters and their indices in the training data:")
print(tokenizer.word_index)
# Out:
# Character counts in the training data:
# OrderedDict([('^', 1366), ('c', 28420), ('n', 8371), ('(', 6973), ('=', 1694), ('o', 3091), (')', 6973), ('1', 4070), ('2', 4028), ('[c@@h]', 804), ('[c@h]', 830), ('$', 1366), ('f', 764), ('3', 2652), ('4', 1060), ('5', 150), ('s', 462), ('-', 972), ('#', 371), ('cl', 137), ('[nh]', 342), ('[c@@]', 5), ('[n+]', 22), ('[o-]', 20), ('.', 15), ('6', 28), ('[sh]', 2), ('br', 4), ('/', 3), ('[c-]', 2), ('7', 8), ('8', 4), ('\\', 1), ('[c@]', 8), ('[2h]', 2)])
# Unique characters and their indices in the training data:
# {'c': 1, 'n': 2, '(': 3, ')': 4, '1': 5, '2': 6, 'o': 7, '3': 8, '=': 9, '^': 10, '$': 11, '4': 12, '-': 13, '[c@h]': 14, '[c@@h]': 15, 'f': 16, 's': 17, '#': 18, '[nh]': 19, '5': 20, 'cl': 21, '6': 22, '[n+]': 23, '[o-]': 24, '.': 25, '7': 26, '[c@]': 27, '[c@@]': 28, 'br': 29, '8': 30, '/': 31, '[sh]': 32, '[c-]': 33, '[2h]': 34, '\\': 35}

# %%
print(x_train_padded.shape)
# Out:
# (1366, 20)

# %%
input_shape = (x_train_padded.shape[1], 1)  # (timesteps, features)
es = EarlyStopping(monitor='val_loss', patience=5
                   , restore_best_weights=True)

clear_session()


model = Sequential()

# Ensure vocab_size is set correctly
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=x_train_padded.shape[1]))

model.add(LSTM(units=5, return_sequences=True, dropout=0))
model.add(Conv1D(32, activation='relu', kernel_size=4))
model.add(Bidirectional(LSTM(32, dropout=0.2, recurrent_dropout=0.0, return_sequences=True)))
model.add(GRU(16, return_sequences=True))
model.add(Bidirectional(LSTM(16, dropout=0.19, recurrent_dropout=0.0, go_backwards=True, return_sequences=True)))
model.add(Conv1D(16, activation='relu', kernel_size=4))
model.add(MaxPool1D(pool_size=2))
model.add(Flatten())
model.add(Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.02)))
model.add(Dense(16, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.02)))
model.add(Dense(1, activation='linear'))  # Change activation if needed

optimizer = Adam(learning_rate=0.005)
model.compile(optimizer=optimizer, loss='mse', metrics=['mse'])

model.summary()

history = model.fit(x_train_padded, y_train,epochs=100, batch_size=16,validation_data = (x_val_padded,y_val) ,callbacks=[es])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 35)            1260
#
#  lstm (LSTM)                 (None, 20, 5)             820
#
#  conv1d (Conv1D)             (None, 17, 32)            672
#
#  bidirectional (Bidirectiona  (None, 17, 64)           16640
#  l)
#
#  gru (GRU)                   (None, 17, 16)            3936
#
#  bidirectional_1 (Bidirectio  (None, 17, 32)           4224
#  nal)
#
#  conv1d_1 (Conv1D)           (None, 14, 16)            2064
#
#  max_pooling1d (MaxPooling1D  (None, 7, 16)            0
#  )
#
#  flatten (Flatten)           (None, 112)               0
#
#  dense (Dense)               (None, 32)                3616
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 33,777
# Trainable params: 33,777
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 86/86 [==============================] - 8s 31ms/step - loss: 8.7886 - mse: 6.4700 - val_loss: 2.4646 - val_mse: 1.2868
# Epoch 2/100
# 86/86 [==============================] - 1s 17ms/step - loss: 2.2838 - mse: 1.3267 - val_loss: 2.0947 - val_mse: 1.3172
# Epoch 3/100
# 86/86 [==============================] - 1s 17ms/step - loss: 2.0208 - mse: 1.3528 - val_loss: 1.8889 - val_mse: 1.3164
# Epoch 4/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.9524 - mse: 1.4354 - val_loss: 2.5458 - val_mse: 2.0843
# Epoch 5/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.7991 - mse: 1.3719 - val_loss: 1.8068 - val_mse: 1.4141
# Epoch 6/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.6632 - mse: 1.3015 - val_loss: 1.6476 - val_mse: 1.3149
# Epoch 7/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.6292 - mse: 1.3156 - val_loss: 1.5871 - val_mse: 1.2939
# Epoch 8/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.5122 - mse: 1.2395 - val_loss: 1.5631 - val_mse: 1.3102
# Epoch 9/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.6467 - mse: 1.3980 - val_loss: 1.8145 - val_mse: 1.5831
# Epoch 10/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.5771 - mse: 1.3513 - val_loss: 2.0818 - val_mse: 1.8573
# Epoch 11/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.4834 - mse: 1.2751 - val_loss: 1.3913 - val_mse: 1.1905
# Epoch 12/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.3297 - mse: 1.1362 - val_loss: 1.4042 - val_mse: 1.2178
# Epoch 13/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.1957 - mse: 1.0168 - val_loss: 1.1605 - val_mse: 0.9920
# Epoch 14/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.1714 - mse: 1.0057 - val_loss: 1.1041 - val_mse: 0.9447
# Epoch 15/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.2231 - mse: 1.0646 - val_loss: 1.1806 - val_mse: 1.0276
# Epoch 16/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.1524 - mse: 1.0011 - val_loss: 1.2332 - val_mse: 1.0871
# Epoch 17/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.1150 - mse: 0.9692 - val_loss: 1.4011 - val_mse: 1.2531
# Epoch 18/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.0582 - mse: 0.9169 - val_loss: 1.0390 - val_mse: 0.8996
# Epoch 19/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.3115 - mse: 1.1684 - val_loss: 1.0266 - val_mse: 0.8872
# Epoch 20/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.0467 - mse: 0.9097 - val_loss: 1.0427 - val_mse: 0.9093
# Epoch 21/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.0127 - mse: 0.8808 - val_loss: 1.0587 - val_mse: 0.9271
# Epoch 22/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.9978 - mse: 0.8705 - val_loss: 1.1578 - val_mse: 1.0294
# Epoch 23/100
# 86/86 [==============================] - 1s 17ms/step - loss: 1.0769 - mse: 0.9524 - val_loss: 1.5280 - val_mse: 1.3979
# Epoch 24/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.9729 - mse: 0.8500 - val_loss: 1.0124 - val_mse: 0.8911
# Epoch 25/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.9471 - mse: 0.8277 - val_loss: 1.3156 - val_mse: 1.2010
# Epoch 26/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.9383 - mse: 0.8215 - val_loss: 0.9284 - val_mse: 0.8139
# Epoch 27/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.9042 - mse: 0.7898 - val_loss: 0.8728 - val_mse: 0.7600
# Epoch 28/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.8808 - mse: 0.7682 - val_loss: 1.0824 - val_mse: 0.9723
# Epoch 29/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.9492 - mse: 0.8385 - val_loss: 0.8426 - val_mse: 0.7322
# Epoch 30/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.8760 - mse: 0.7666 - val_loss: 0.8955 - val_mse: 0.7854
# Epoch 31/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.8677 - mse: 0.7591 - val_loss: 0.9505 - val_mse: 0.8429
# Epoch 32/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.8496 - mse: 0.7423 - val_loss: 0.8286 - val_mse: 0.7225
# Epoch 33/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.7917 - mse: 0.6836 - val_loss: 0.8597 - val_mse: 0.7401
# Epoch 34/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.7943 - mse: 0.6803 - val_loss: 0.8141 - val_mse: 0.7079
# Epoch 35/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.7689 - mse: 0.6662 - val_loss: 0.9393 - val_mse: 0.8358
# Epoch 36/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.7689 - mse: 0.6676 - val_loss: 0.8774 - val_mse: 0.7756
# Epoch 37/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.7459 - mse: 0.6459 - val_loss: 0.8880 - val_mse: 0.7897
# Epoch 38/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.7509 - mse: 0.6516 - val_loss: 0.9133 - val_mse: 0.8129
# Epoch 39/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.7046 - mse: 0.6069 - val_loss: 0.7968 - val_mse: 0.7005
# Epoch 40/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.7709 - mse: 0.6742 - val_loss: 0.8237 - val_mse: 0.7239
# Epoch 41/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.7221 - mse: 0.6203 - val_loss: 0.8056 - val_mse: 0.7079
# Epoch 42/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.6707 - mse: 0.5716 - val_loss: 0.7951 - val_mse: 0.6966
# Epoch 43/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.7192 - mse: 0.6245 - val_loss: 0.9042 - val_mse: 0.8117
# Epoch 44/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.7349 - mse: 0.6424 - val_loss: 0.7943 - val_mse: 0.7035
# Epoch 45/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.7065 - mse: 0.6102 - val_loss: 0.7805 - val_mse: 0.6808
# Epoch 46/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.6336 - mse: 0.5406 - val_loss: 0.7975 - val_mse: 0.7083
# Epoch 47/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.6407 - mse: 0.5516 - val_loss: 0.8213 - val_mse: 0.7332
# Epoch 48/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.6432 - mse: 0.5551 - val_loss: 0.8362 - val_mse: 0.7506
# Epoch 49/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.6620 - mse: 0.5753 - val_loss: 0.8168 - val_mse: 0.7313
# Epoch 50/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.6977 - mse: 0.6112 - val_loss: 0.7731 - val_mse: 0.6869
# Epoch 51/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.6804 - mse: 0.5943 - val_loss: 0.8390 - val_mse: 0.7535
# Epoch 52/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.6663 - mse: 0.5743 - val_loss: 0.8010 - val_mse: 0.7063
# Epoch 53/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.6382 - mse: 0.5499 - val_loss: 0.7936 - val_mse: 0.7077
# Epoch 54/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.6226 - mse: 0.5329 - val_loss: 0.7565 - val_mse: 0.6730
# Epoch 55/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.7023 - mse: 0.6099 - val_loss: 0.8081 - val_mse: 0.7058
# Epoch 56/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.6019 - mse: 0.5114 - val_loss: 0.7544 - val_mse: 0.6676
# Epoch 57/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.5978 - mse: 0.5144 - val_loss: 0.7785 - val_mse: 0.6965
# Epoch 58/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.5891 - mse: 0.5080 - val_loss: 0.7356 - val_mse: 0.6563
# Epoch 59/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.5761 - mse: 0.4941 - val_loss: 0.7384 - val_mse: 0.6562
# Epoch 60/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.6352 - mse: 0.5547 - val_loss: 0.7895 - val_mse: 0.7096
# Epoch 61/100
# 86/86 [==============================] - 1s 16ms/step - loss: 0.5936 - mse: 0.5147 - val_loss: 0.7670 - val_mse: 0.6892
# Epoch 62/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.5623 - mse: 0.4847 - val_loss: 0.7613 - val_mse: 0.6837
# Epoch 63/100
# 86/86 [==============================] - 1s 17ms/step - loss: 0.5801 - mse: 0.5031 - val_loss: 0.7703 - val_mse: 0.6933

# %%
# input_shape = (x_train_padded.shape[1], 1)  # (timesteps, features)
# es = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)


# model = Sequential()

# model.add(LSTM(units=64, input_shape=input_shape, dropout=0.19, recurrent_dropout=0.0, return_sequences=False))
# model.add(Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=0.005, l2=0.01)))
# model.add(Dropout(0.1)) 
# model.add(Dense(16, activation='relu', kernel_regularizer=l1_l2(l1=0.005, l2=0.01)))
# model.add(Dense(1, activation='linear'))

# optimizer = Adam(learning_rate=0.005)
# model.compile(optimizer=optimizer, loss='mse', metrics=['mse'])

# model.summary()

# history = model.fit(x_train_padded, y_train,epochs=10000, batch_size=32,validation_data = (x_val_padded,y_val) ,callbacks=[es])

# %%
test = pd.read_csv('./test.csv')
test = test.drop(['ID'],axis=1)

# %%
test['Smiles'] = test['Smiles'].apply(tokenize)
test = test['Smiles'].tolist()

# Tokenize the SMILES strings
tokenizer = Tokenizer(char_level=True, filters='')
tokenizer.fit_on_texts(test)
test_sequences = tokenizer.texts_to_sequences(test)

# Padding sequences to have the same length (adjust maxlen as necessary)
test_padded = pad_sequences(test_sequences, maxlen=maxlen, padding='post')

# %%
y_pred = model.predict(test_padded)

# %%
submit = pd.read_csv('./sample_submission.csv')
submit['IC50_nM'] = pIC50_to_IC50(y_pred)
submit.head()
# Out:
#          ID    IC50_nM
# 0  TEST_000  14.348862
# 1  TEST_001   7.030926
# 2  TEST_002   6.493517
# 3  TEST_003   8.844754
# 4  TEST_004   8.844754

# %%
submit.to_csv('./baseline_submit.csv', index=False)
