# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np
import random
import os
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import xgboost
import catboost


from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Descriptors
from rdkit import RDConfig
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from rdkit.Chem import PandasTools as PandasTools
from rdkit import DataStructs
from rdkit.Chem.Subshape import SubshapeBuilder,SubshapeAligner,SubshapeObjects

# %%
def pIC50_to_IC50(pic50_values):
    """Convert pIC50 values to IC50 (nM)."""
    return 10 ** (9 - pic50_values)

# %%
CFG = {
    'NBITS':2048,
    'SEED':42,
}

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(CFG['SEED']) # Seed 고정

# %% [markdown]
# ### DataLoad

# %%
# SMILES 데이터를 분자 지문으로 변환
def smiles_to_fingerprint(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=CFG['NBITS'])
        return np.array(fp)
    else:
        return np.zeros((CFG['NBITS'],))

# %%
# 학습 ChEMBL 데이터 로드
df = pd.read_csv('train.csv')  # 예시 파일 이름
df.head()
# Out:
#   Molecule ChEMBL ID Standard Type Standard Relation  Standard Value  \
# 0      CHEMBL4443947          IC50               '='           0.022
# 1      CHEMBL4556091          IC50               '='           0.026
# 2      CHEMBL4566431          IC50               '='           0.078
# 3      CHEMBL4545898          IC50               '='           0.081
# 4      CHEMBL4448950          IC50               '='           0.099
#
#   Standard Units  pChEMBL Value Assay ChEMBL ID Target ChEMBL ID  \
# 0             nM          10.66   CHEMBL4361896       CHEMBL3778
# 1             nM          10.59   CHEMBL4345131       CHEMBL3778
# 2             nM          10.11   CHEMBL4345131       CHEMBL3778
# 3             nM          10.09   CHEMBL4345131       CHEMBL3778
# 4             nM          10.00   CHEMBL4361896       CHEMBL3778
#
#                                   Target Name Target Organism     Target Type  \
# 0  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 1  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 2  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 3  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 4  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
#
#   Document ChEMBL ID  IC50_nM  pIC50  \
# 0      CHEMBL4359855    0.022  10.66
# 1      CHEMBL4342485    0.026  10.59
# 2      CHEMBL4342485    0.078  10.11
# 3      CHEMBL4342485    0.081  10.09
# 4      CHEMBL4359855    0.099  10.00
#
#                                               Smiles
# 0  CN[C@@H](C)C(=O)N[C@H](C(=O)N1C[C@@H](NC(=O)CC...
# 1  CC(C)(O)[C@H](F)CN1Cc2cc(NC(=O)c3cnn4cccnc34)c...
# 2  CC(C)(O)[C@H](F)CN1Cc2cc(NC(=O)c3cnn4cccnc34)c...
# 3  CC(C)(O)[C@H](F)CN1Cc2cc(NC(=O)c3cnn4cccnc34)c...
# 4  COc1cc2c(OC[C@@H]3CCC(=O)N3)ncc(C#CCCCCCCCCCCC...

# %% [markdown]
# ### Data Pre-processing

# %%
#제거 변수

delete = ['Molecule ChEMBL ID','Standard Type','Standard Relation','Standard Value','Standard Units','pChEMBL Value','Assay ChEMBL ID','Target ChEMBL ID','Target Name','Target Organism',
          'Target Type','Document ChEMBL ID','pIC50','IC50_nM']

# %%
y_train = df['pIC50'].values
x_train = df.drop(delete ,axis=1)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train,y_train, test_size=0.3)

# %% [markdown]
# ### Train & Validation

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense,Input,Dropout,LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.regularizers import l1_l2

# %%
x_train = x_train['Smiles'].tolist()
x_val = x_val['Smiles'].tolist()
# Tokenize the SMILES strings
tokenizer = Tokenizer(char_level=True, filters='')
tokenizer.fit_on_texts(x_train)
train_sequences = tokenizer.texts_to_sequences(x_train)
val_sequences = tokenizer.texts_to_sequences(x_val)

# Padding sequences to have the same length (adjust maxlen as necessary)
maxlen = 20  # This should be set according to your data
x_train_padded = pad_sequences(train_sequences, maxlen=maxlen, padding='post')
x_val_padded = pad_sequences(val_sequences, maxlen=maxlen, padding='post')

# %%
print(x_train_padded.shape)
# Out:
# (1366, 20)

# %%
input_shape = (x_train_padded.shape[1], 1)  # (timesteps, features)
es = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)


model = Sequential()

model.add(LSTM(units=64, input_shape=input_shape, dropout=0.19, recurrent_dropout=0.0, return_sequences=False))
model.add(Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=0.005, l2=0.01)))
model.add(Dropout(0.1)) 
model.add(Dense(16, activation='relu', kernel_regularizer=l1_l2(l1=0.005, l2=0.01)))
model.add(Dense(1, activation='linear'))

optimizer = Adam(learning_rate=0.005)
model.compile(optimizer=optimizer, loss='mse', metrics=['mse'])

model.summary()

history = model.fit(x_train_padded, y_train,epochs=10000, batch_size=32,validation_data = (x_val_padded,y_val) ,callbacks=[es])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 64)                16896
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 16)                528
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 19,521
# Trainable params: 19,521
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10000
# 43/43 [==============================] - 2s 12ms/step - loss: 8.7092 - mse: 7.0267 - val_loss: 2.4630 - val_mse: 1.2489
# Epoch 2/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 3.0672 - mse: 1.9976 - val_loss: 2.1726 - val_mse: 1.2189
# Epoch 3/10000
# 43/43 [==============================] - 0s 7ms/step - loss: 2.7003 - mse: 1.8145 - val_loss: 2.0923 - val_mse: 1.2646
# Epoch 4/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 2.5174 - mse: 1.7419 - val_loss: 2.1981 - val_mse: 1.4737
# Epoch 5/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 2.4517 - mse: 1.7573 - val_loss: 1.9938 - val_mse: 1.3402
# Epoch 6/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 2.2892 - mse: 1.6643 - val_loss: 2.0869 - val_mse: 1.4978
# Epoch 7/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 2.2271 - mse: 1.6610 - val_loss: 1.7254 - val_mse: 1.1846
# Epoch 8/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 2.0933 - mse: 1.5752 - val_loss: 1.8398 - val_mse: 1.3448
# Epoch 9/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 2.0183 - mse: 1.5407 - val_loss: 1.6413 - val_mse: 1.1828
# Epoch 10/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.8756 - mse: 1.4343 - val_loss: 1.6075 - val_mse: 1.1815
# Epoch 11/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.8776 - mse: 1.4665 - val_loss: 1.5813 - val_mse: 1.1839
# Epoch 12/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.8563 - mse: 1.4718 - val_loss: 1.7216 - val_mse: 1.3504
# Epoch 13/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.7587 - mse: 1.3956 - val_loss: 1.5287 - val_mse: 1.1749
# Epoch 14/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.7623 - mse: 1.4199 - val_loss: 1.5785 - val_mse: 1.2460
# Epoch 15/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.6889 - mse: 1.3631 - val_loss: 1.8747 - val_mse: 1.5610
# Epoch 16/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.6566 - mse: 1.3485 - val_loss: 1.7630 - val_mse: 1.4646
# Epoch 17/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.5944 - mse: 1.2998 - val_loss: 1.5523 - val_mse: 1.2648
# Epoch 18/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.6773 - mse: 1.3973 - val_loss: 1.6665 - val_mse: 1.3951
# Epoch 19/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.6266 - mse: 1.3589 - val_loss: 1.7497 - val_mse: 1.4886
# Epoch 20/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.5974 - mse: 1.3380 - val_loss: 1.5076 - val_mse: 1.2544
# Epoch 21/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.5492 - mse: 1.3031 - val_loss: 1.6433 - val_mse: 1.4067
# Epoch 22/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.4870 - mse: 1.2514 - val_loss: 1.4059 - val_mse: 1.1713
# Epoch 23/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.5620 - mse: 1.3357 - val_loss: 1.8984 - val_mse: 1.6803
# Epoch 24/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.4693 - mse: 1.2533 - val_loss: 1.8533 - val_mse: 1.6451
# Epoch 25/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.4775 - mse: 1.2694 - val_loss: 1.4104 - val_mse: 1.2061
# Epoch 26/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.4165 - mse: 1.2158 - val_loss: 1.7210 - val_mse: 1.5266
# Epoch 27/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.4220 - mse: 1.2274 - val_loss: 1.6085 - val_mse: 1.4197
# Epoch 28/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.3901 - mse: 1.2029 - val_loss: 1.3991 - val_mse: 1.2126
# Epoch 29/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.3562 - mse: 1.1749 - val_loss: 1.2525 - val_mse: 1.0721
# Epoch 30/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.4575 - mse: 1.2803 - val_loss: 1.5339 - val_mse: 1.3593
# Epoch 31/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.3510 - mse: 1.1773 - val_loss: 1.2312 - val_mse: 1.0606
# Epoch 32/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.5087 - mse: 1.3428 - val_loss: 1.2666 - val_mse: 1.1032
# Epoch 33/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.3221 - mse: 1.1650 - val_loss: 1.5477 - val_mse: 1.3962
# Epoch 34/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.3322 - mse: 1.1782 - val_loss: 1.2763 - val_mse: 1.1193
# Epoch 35/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.3346 - mse: 1.1836 - val_loss: 1.2013 - val_mse: 1.0506
# Epoch 36/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.2978 - mse: 1.1523 - val_loss: 1.3122 - val_mse: 1.1686
# Epoch 37/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.2859 - mse: 1.1436 - val_loss: 1.2057 - val_mse: 1.0606
# Epoch 38/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.2807 - mse: 1.1410 - val_loss: 1.2068 - val_mse: 1.0688
# Epoch 39/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.2384 - mse: 1.1042 - val_loss: 1.1613 - val_mse: 1.0260
# Epoch 40/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.2432 - mse: 1.1133 - val_loss: 1.3680 - val_mse: 1.2440
# Epoch 41/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.2212 - mse: 1.0957 - val_loss: 1.4375 - val_mse: 1.3119
# Epoch 42/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.2088 - mse: 1.0784 - val_loss: 1.2317 - val_mse: 1.1032
# Epoch 43/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.1776 - mse: 1.0539 - val_loss: 1.2572 - val_mse: 1.1382
# Epoch 44/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.1780 - mse: 1.0609 - val_loss: 1.3175 - val_mse: 1.2019
# Epoch 45/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.1279 - mse: 1.0124 - val_loss: 1.3056 - val_mse: 1.1895
# Epoch 46/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.1514 - mse: 1.0385 - val_loss: 1.2439 - val_mse: 1.1341
# Epoch 47/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.1212 - mse: 1.0114 - val_loss: 1.1308 - val_mse: 1.0218
# Epoch 48/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.1153 - mse: 1.0086 - val_loss: 1.2493 - val_mse: 1.1439
# Epoch 49/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.1164 - mse: 1.0124 - val_loss: 1.3605 - val_mse: 1.2626
# Epoch 50/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.0765 - mse: 0.9748 - val_loss: 1.2897 - val_mse: 1.1870
# Epoch 51/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.1448 - mse: 1.0456 - val_loss: 1.5215 - val_mse: 1.4255
# Epoch 52/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.1200 - mse: 1.0226 - val_loss: 1.2151 - val_mse: 1.1205
# Epoch 53/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.0674 - mse: 0.9727 - val_loss: 1.0264 - val_mse: 0.9287
# Epoch 54/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.1068 - mse: 1.0115 - val_loss: 1.1273 - val_mse: 1.0306
# Epoch 55/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.1125 - mse: 1.0206 - val_loss: 1.2219 - val_mse: 1.1291
# Epoch 56/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.0434 - mse: 0.9530 - val_loss: 1.0494 - val_mse: 0.9604
# Epoch 57/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.0656 - mse: 0.9767 - val_loss: 1.0874 - val_mse: 0.9973
# Epoch 58/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.0591 - mse: 0.9706 - val_loss: 1.1454 - val_mse: 1.0541
# Epoch 59/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.0284 - mse: 0.9411 - val_loss: 1.0681 - val_mse: 0.9816
# Epoch 60/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.0842 - mse: 0.9976 - val_loss: 1.0943 - val_mse: 1.0089
# Epoch 61/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.0565 - mse: 0.9715 - val_loss: 1.1957 - val_mse: 1.1127
# Epoch 62/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.0320 - mse: 0.9473 - val_loss: 0.9952 - val_mse: 0.9087
# Epoch 63/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.0427 - mse: 0.9582 - val_loss: 1.1016 - val_mse: 1.0162
# Epoch 64/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.0198 - mse: 0.9351 - val_loss: 1.0895 - val_mse: 1.0052
# Epoch 65/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 0.9967 - mse: 0.9126 - val_loss: 0.9690 - val_mse: 0.8820
# Epoch 66/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.0042 - mse: 0.9200 - val_loss: 1.1298 - val_mse: 1.0472
# Epoch 67/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 0.9767 - mse: 0.8932 - val_loss: 1.1261 - val_mse: 1.0445
# Epoch 68/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 1.0150 - mse: 0.9313 - val_loss: 0.9429 - val_mse: 0.8572
# Epoch 69/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 1.0188 - mse: 0.9360 - val_loss: 1.0690 - val_mse: 0.9877
# Epoch 70/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 0.9944 - mse: 0.9134 - val_loss: 0.9887 - val_mse: 0.9074
# Epoch 71/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 0.9584 - mse: 0.8777 - val_loss: 1.0922 - val_mse: 1.0124
# Epoch 72/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 0.9884 - mse: 0.9075 - val_loss: 1.0223 - val_mse: 0.9406
# Epoch 73/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 0.9648 - mse: 0.8852 - val_loss: 1.1548 - val_mse: 1.0747
# Epoch 74/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 0.9553 - mse: 0.8750 - val_loss: 1.0218 - val_mse: 0.9432
# Epoch 75/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 0.9494 - mse: 0.8712 - val_loss: 1.1226 - val_mse: 1.0455
# Epoch 76/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 0.9404 - mse: 0.8633 - val_loss: 1.0505 - val_mse: 0.9732
# Epoch 77/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 0.9145 - mse: 0.8343 - val_loss: 1.1755 - val_mse: 1.0954
# Epoch 78/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 0.9245 - mse: 0.8455 - val_loss: 1.0836 - val_mse: 1.0055
# Epoch 79/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 0.9030 - mse: 0.8244 - val_loss: 1.1446 - val_mse: 1.0660
# Epoch 80/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 0.9600 - mse: 0.8808 - val_loss: 1.0471 - val_mse: 0.9668
# Epoch 81/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 0.9524 - mse: 0.8755 - val_loss: 0.9901 - val_mse: 0.9109
# Epoch 82/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 0.9573 - mse: 0.8801 - val_loss: 1.0191 - val_mse: 0.9411
# Epoch 83/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 0.9416 - mse: 0.8647 - val_loss: 1.1706 - val_mse: 1.0944
# Epoch 84/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 0.9144 - mse: 0.8385 - val_loss: 1.1089 - val_mse: 1.0334
# Epoch 85/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 0.8799 - mse: 0.8050 - val_loss: 1.0561 - val_mse: 0.9813
# Epoch 86/10000
# 43/43 [==============================] - 0s 6ms/step - loss: 0.8709 - mse: 0.7962 - val_loss: 1.0350 - val_mse: 0.9582
# Epoch 87/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 0.8847 - mse: 0.8074 - val_loss: 0.9532 - val_mse: 0.8755
# Epoch 88/10000
# 43/43 [==============================] - 0s 5ms/step - loss: 0.9056 - mse: 0.8318 - val_loss: 1.2629 - val_mse: 1.1910

# %%
test = pd.read_csv('./test.csv')
test = test.drop(['ID'],axis=1)

# %%
test = test['Smiles'].tolist()

# Tokenize the SMILES strings
tokenizer = Tokenizer(char_level=True, filters='')
tokenizer.fit_on_texts(test)
test_sequences = tokenizer.texts_to_sequences(test)

# Padding sequences to have the same length (adjust maxlen as necessary)
test_padded = pad_sequences(test_sequences, maxlen=maxlen, padding='post')

# %%
y_pred = model.predict(test_padded)

# %%
submit = pd.read_csv('./sample_submission.csv')
submit['IC50_nM'] = pIC50_to_IC50(y_pred)
submit.head()
# Out:
#          ID    IC50_nM
# 0  TEST_000  33.876209
# 1  TEST_001   8.841764
# 2  TEST_002   7.479437
# 3  TEST_003   6.748695
# 4  TEST_004   6.748695

# %%
submit.to_csv('./baseline_submit.csv', index=False)
