# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np
import random
import os
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import xgboost
import catboost


from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Descriptors
from rdkit import RDConfig
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from rdkit.Chem import PandasTools as PandasTools
from rdkit import DataStructs
from rdkit.Chem.Subshape import SubshapeBuilder,SubshapeAligner,SubshapeObjects

# %%
def pIC50_to_IC50(pic50_values):
    """Convert pIC50 values to IC50 (nM)."""
    return 10 ** (9 - pic50_values)

# %%
CFG = {
    'NBITS':2048,
    'SEED':42,
}

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(CFG['SEED']) # Seed 고정

# %% [markdown]
# ### DataLoad

# %%
# SMILES 데이터를 분자 지문으로 변환
def smiles_to_fingerprint(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=CFG['NBITS'])
        return np.array(fp)
    else:
        return np.zeros((CFG['NBITS'],))

# %%
# 학습 ChEMBL 데이터 로드
df = pd.read_csv('train.csv')  # 예시 파일 이름
df.head()
# Out:
#   Molecule ChEMBL ID Standard Type Standard Relation  Standard Value  \
# 0      CHEMBL4443947          IC50               '='           0.022
# 1      CHEMBL4556091          IC50               '='           0.026
# 2      CHEMBL4566431          IC50               '='           0.078
# 3      CHEMBL4545898          IC50               '='           0.081
# 4      CHEMBL4448950          IC50               '='           0.099
#
#   Standard Units  pChEMBL Value Assay ChEMBL ID Target ChEMBL ID  \
# 0             nM          10.66   CHEMBL4361896       CHEMBL3778
# 1             nM          10.59   CHEMBL4345131       CHEMBL3778
# 2             nM          10.11   CHEMBL4345131       CHEMBL3778
# 3             nM          10.09   CHEMBL4345131       CHEMBL3778
# 4             nM          10.00   CHEMBL4361896       CHEMBL3778
#
#                                   Target Name Target Organism     Target Type  \
# 0  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 1  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 2  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 3  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
# 4  Interleukin-1 receptor-associated kinase 4    Homo sapiens  SINGLE PROTEIN
#
#   Document ChEMBL ID  IC50_nM  pIC50  \
# 0      CHEMBL4359855    0.022  10.66
# 1      CHEMBL4342485    0.026  10.59
# 2      CHEMBL4342485    0.078  10.11
# 3      CHEMBL4342485    0.081  10.09
# 4      CHEMBL4359855    0.099  10.00
#
#                                               Smiles
# 0  CN[C@@H](C)C(=O)N[C@H](C(=O)N1C[C@@H](NC(=O)CC...
# 1  CC(C)(O)[C@H](F)CN1Cc2cc(NC(=O)c3cnn4cccnc34)c...
# 2  CC(C)(O)[C@H](F)CN1Cc2cc(NC(=O)c3cnn4cccnc34)c...
# 3  CC(C)(O)[C@H](F)CN1Cc2cc(NC(=O)c3cnn4cccnc34)c...
# 4  COc1cc2c(OC[C@@H]3CCC(=O)N3)ncc(C#CCCCCCCCCCCC...

# %% [markdown]
# ### Data Pre-processing

# %%
#제거 변수

delete = ['Molecule ChEMBL ID','Standard Type','Standard Relation','Standard Value','Standard Units','pChEMBL Value','Assay ChEMBL ID','Target ChEMBL ID','Target Name','Target Organism',
          'Target Type','Document ChEMBL ID','pIC50','IC50_nM']

# %%
y_train = df['pIC50'].values
x_train = df.drop(delete ,axis=1)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train,y_train, test_size=0.3)

# %% [markdown]
# ### Train & Validation

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense,Input,Dropout,LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.regularizers import l1_l2

# %%
x_train = x_train['Smiles'].tolist()
x_val = x_val['Smiles'].tolist()
# Tokenize the SMILES strings
tokenizer = Tokenizer(char_level=True, filters='')
tokenizer.fit_on_texts(x_train)
train_sequences = tokenizer.texts_to_sequences(x_train)
val_sequences = tokenizer.texts_to_sequences(x_val)

# Padding sequences to have the same length (adjust maxlen as necessary)
maxlen = 10  # This should be set according to your data
x_train_padded = pad_sequences(train_sequences, maxlen=maxlen, padding='post')
x_val_padded = pad_sequences(val_sequences, maxlen=maxlen, padding='post')

# %%
print(x_train_padded.shape)
# Out:
# (1366, 10)

# %%
input_shape = (x_train_padded.shape[1], 1)  # (timesteps, features)
es = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)


model = Sequential()
    
model.add(LSTM(units=64, input_shape=input_shape, dropout=0.19, recurrent_dropout=0.0))
model.add(Dense(32, activation='relu',kernel_regularizer = l1_l2(l1 = 0.005,l2 = 0.01)))
model.add(Dense(16, activation='relu',kernel_regularizer = l1_l2(l1 = 0.005,l2 = 0.01)))
model.add(Dense(8, activation='relu',kernel_regularizer = l1_l2(l1 = 0.005,l2 = 0.01)))
model.add(Dense(1, activation='linear'))


optimizer = Adam(learning_rate=0.005)
model.compile(optimizer=optimizer, loss='mse', metrics=['mse'])

model.summary()

model.fit(x_train_padded, y_train,epochs=10000, batch_size=16,validation_data = [x_val_padded,y_val] ,callbacks=[es])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 19,649
# Trainable params: 19,649
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10000
# 86/86 [==============================] - 6s 10ms/step - loss: 5.9140 - mse: 4.0994 - val_loss: 2.6147 - val_mse: 1.2442
# Epoch 2/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 2.4713 - mse: 1.2956 - val_loss: 2.2260 - val_mse: 1.2164
# Epoch 3/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 2.1564 - mse: 1.2585 - val_loss: 1.9830 - val_mse: 1.1884
# Epoch 4/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 2.0016 - mse: 1.2821 - val_loss: 1.9087 - val_mse: 1.2619
# Epoch 5/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 1.8945 - mse: 1.2980 - val_loss: 1.7962 - val_mse: 1.2479
# Epoch 6/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.8896 - mse: 1.3818 - val_loss: 1.7604 - val_mse: 1.2930
# Epoch 7/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 1.7196 - mse: 1.2779 - val_loss: 1.6413 - val_mse: 1.2245
# Epoch 8/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.6268 - mse: 1.2347 - val_loss: 1.5575 - val_mse: 1.1859
# Epoch 9/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.6110 - mse: 1.2573 - val_loss: 1.7723 - val_mse: 1.4387
# Epoch 10/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.5589 - mse: 1.2368 - val_loss: 1.4868 - val_mse: 1.1765
# Epoch 11/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.5406 - mse: 1.2445 - val_loss: 1.4650 - val_mse: 1.1788
# Epoch 12/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.5379 - mse: 1.2604 - val_loss: 1.6172 - val_mse: 1.3443
# Epoch 13/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 1.5218 - mse: 1.2611 - val_loss: 1.4175 - val_mse: 1.1648
# Epoch 14/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.4980 - mse: 1.2516 - val_loss: 1.3798 - val_mse: 1.1416
# Epoch 15/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 1.5213 - mse: 1.2871 - val_loss: 1.3514 - val_mse: 1.1250
# Epoch 16/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 1.4723 - mse: 1.2482 - val_loss: 1.4978 - val_mse: 1.2738
# Epoch 17/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 1.4493 - mse: 1.2360 - val_loss: 1.3472 - val_mse: 1.1390
# Epoch 18/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 1.4631 - mse: 1.2589 - val_loss: 1.3570 - val_mse: 1.1510
# Epoch 19/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 1.3551 - mse: 1.1597 - val_loss: 1.3436 - val_mse: 1.1550
# Epoch 20/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 1.3128 - mse: 1.1239 - val_loss: 1.1993 - val_mse: 1.0169
# Epoch 21/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.2894 - mse: 1.1074 - val_loss: 1.2104 - val_mse: 1.0336
# Epoch 22/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.2447 - mse: 1.0684 - val_loss: 1.1824 - val_mse: 1.0104
# Epoch 23/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 1.2443 - mse: 1.0744 - val_loss: 1.1775 - val_mse: 1.0078
# Epoch 24/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.1799 - mse: 1.0171 - val_loss: 1.1457 - val_mse: 0.9845
# Epoch 25/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.2128 - mse: 1.0532 - val_loss: 1.2657 - val_mse: 1.1118
# Epoch 26/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.1794 - mse: 1.0248 - val_loss: 1.1251 - val_mse: 0.9733
# Epoch 27/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.1952 - mse: 1.0445 - val_loss: 1.2011 - val_mse: 1.0513
# Epoch 28/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.1827 - mse: 1.0342 - val_loss: 1.1392 - val_mse: 0.9936
# Epoch 29/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.1243 - mse: 0.9789 - val_loss: 1.0818 - val_mse: 0.9391
# Epoch 30/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.1659 - mse: 1.0247 - val_loss: 1.2080 - val_mse: 1.0675
# Epoch 31/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 1.1517 - mse: 1.0144 - val_loss: 1.1262 - val_mse: 0.9906
# Epoch 32/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 1.1023 - mse: 0.9678 - val_loss: 1.0658 - val_mse: 0.9340
# Epoch 33/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 1.1745 - mse: 1.0423 - val_loss: 1.3310 - val_mse: 1.2003
# Epoch 34/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 1.1157 - mse: 0.9859 - val_loss: 1.2242 - val_mse: 1.0908
# Epoch 35/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 1.1344 - mse: 1.0065 - val_loss: 1.3050 - val_mse: 1.1745
# Epoch 36/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 1.1506 - mse: 1.0245 - val_loss: 1.1553 - val_mse: 1.0300
# Epoch 37/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 1.1147 - mse: 0.9884 - val_loss: 1.1457 - val_mse: 1.0227
# Epoch 38/10000
# 86/86 [==============================] - 1s 8ms/step - loss: 1.1234 - mse: 1.0005 - val_loss: 1.1686 - val_mse: 1.0456
# Epoch 39/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.1649 - mse: 1.0432 - val_loss: 1.8214 - val_mse: 1.6968
# Epoch 40/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 1.0768 - mse: 0.9586 - val_loss: 1.1555 - val_mse: 1.0404
# Epoch 41/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.0806 - mse: 0.9629 - val_loss: 1.2387 - val_mse: 1.1191
# Epoch 42/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 1.0512 - mse: 0.9344 - val_loss: 1.3548 - val_mse: 1.2366
# Epoch 43/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.1024 - mse: 0.9875 - val_loss: 1.0905 - val_mse: 0.9788
# Epoch 44/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.0574 - mse: 0.9442 - val_loss: 1.1391 - val_mse: 1.0284
# Epoch 45/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 1.0133 - mse: 0.9026 - val_loss: 1.2424 - val_mse: 1.1312
# Epoch 46/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.0772 - mse: 0.9653 - val_loss: 1.4218 - val_mse: 1.3088
# Epoch 47/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 1.0155 - mse: 0.9064 - val_loss: 1.2292 - val_mse: 1.1217
# Epoch 48/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.0308 - mse: 0.9229 - val_loss: 1.1033 - val_mse: 0.9953
# Epoch 49/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 1.0221 - mse: 0.9148 - val_loss: 1.0784 - val_mse: 0.9746
# Epoch 50/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.0756 - mse: 0.9708 - val_loss: 0.9760 - val_mse: 0.8731
# Epoch 51/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.0068 - mse: 0.9024 - val_loss: 1.0567 - val_mse: 0.9557
# Epoch 52/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9747 - mse: 0.8710 - val_loss: 1.3986 - val_mse: 1.2954
# Epoch 53/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.0093 - mse: 0.9072 - val_loss: 1.2413 - val_mse: 1.1364
# Epoch 54/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9599 - mse: 0.8554 - val_loss: 1.0443 - val_mse: 0.9430
# Epoch 55/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.0367 - mse: 0.9347 - val_loss: 1.0636 - val_mse: 0.9642
# Epoch 56/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9579 - mse: 0.8586 - val_loss: 1.2093 - val_mse: 1.1058
# Epoch 57/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9878 - mse: 0.8878 - val_loss: 1.1558 - val_mse: 1.0566
# Epoch 58/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9876 - mse: 0.8893 - val_loss: 1.1636 - val_mse: 1.0683
# Epoch 59/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9448 - mse: 0.8500 - val_loss: 1.3223 - val_mse: 1.2265
# Epoch 60/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9566 - mse: 0.8589 - val_loss: 1.0679 - val_mse: 0.9758
# Epoch 61/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 1.0134 - mse: 0.9176 - val_loss: 1.0222 - val_mse: 0.9294
# Epoch 62/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9678 - mse: 0.8739 - val_loss: 1.1504 - val_mse: 1.0562
# Epoch 63/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9529 - mse: 0.8605 - val_loss: 1.0458 - val_mse: 0.9569
# Epoch 64/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9363 - mse: 0.8456 - val_loss: 1.0609 - val_mse: 0.9723
# Epoch 65/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9877 - mse: 0.8983 - val_loss: 1.0899 - val_mse: 1.0002
# Epoch 66/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9441 - mse: 0.8536 - val_loss: 1.4036 - val_mse: 1.3119
# Epoch 67/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9217 - mse: 0.8328 - val_loss: 1.1951 - val_mse: 1.1059
# Epoch 68/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9397 - mse: 0.8526 - val_loss: 0.9824 - val_mse: 0.8964
# Epoch 69/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9810 - mse: 0.8948 - val_loss: 1.3580 - val_mse: 1.2708
# Epoch 70/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9505 - mse: 0.8642 - val_loss: 1.0148 - val_mse: 0.9297
# Epoch 71/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9789 - mse: 0.8944 - val_loss: 1.0416 - val_mse: 0.9602
# Epoch 72/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.9232 - mse: 0.8397 - val_loss: 1.1183 - val_mse: 1.0376
# Epoch 73/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9386 - mse: 0.8561 - val_loss: 1.0657 - val_mse: 0.9845
# Epoch 74/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.9741 - mse: 0.8920 - val_loss: 0.9984 - val_mse: 0.9193
# Epoch 75/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9146 - mse: 0.8331 - val_loss: 1.3760 - val_mse: 1.2924
# Epoch 76/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9217 - mse: 0.8421 - val_loss: 1.0068 - val_mse: 0.9287
# Epoch 77/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8929 - mse: 0.8142 - val_loss: 1.0779 - val_mse: 0.9999
# Epoch 78/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8923 - mse: 0.8139 - val_loss: 1.1182 - val_mse: 1.0360
# Epoch 79/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9465 - mse: 0.8672 - val_loss: 1.1051 - val_mse: 1.0277
# Epoch 80/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.9400 - mse: 0.8622 - val_loss: 0.9703 - val_mse: 0.8919
# Epoch 81/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.9189 - mse: 0.8421 - val_loss: 1.0461 - val_mse: 0.9722
# Epoch 82/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.9287 - mse: 0.8546 - val_loss: 1.1136 - val_mse: 1.0392
# Epoch 83/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8899 - mse: 0.8159 - val_loss: 1.0285 - val_mse: 0.9525
# Epoch 84/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9084 - mse: 0.8343 - val_loss: 1.0050 - val_mse: 0.9322
# Epoch 85/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8739 - mse: 0.7996 - val_loss: 1.0815 - val_mse: 1.0083
# Epoch 86/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8530 - mse: 0.7797 - val_loss: 1.0234 - val_mse: 0.9502
# Epoch 87/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8883 - mse: 0.8159 - val_loss: 0.9917 - val_mse: 0.9186
# Epoch 88/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.8690 - mse: 0.7971 - val_loss: 1.2016 - val_mse: 1.1292
# Epoch 89/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8591 - mse: 0.7860 - val_loss: 1.0587 - val_mse: 0.9857
# Epoch 90/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.9107 - mse: 0.8392 - val_loss: 0.9177 - val_mse: 0.8493
# Epoch 91/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.8764 - mse: 0.8057 - val_loss: 1.0106 - val_mse: 0.9397
# Epoch 92/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8591 - mse: 0.7890 - val_loss: 0.9679 - val_mse: 0.8972
# Epoch 93/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.8420 - mse: 0.7714 - val_loss: 0.9935 - val_mse: 0.9228
# Epoch 94/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.8614 - mse: 0.7908 - val_loss: 1.0908 - val_mse: 1.0207
# Epoch 95/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.8920 - mse: 0.8211 - val_loss: 0.9752 - val_mse: 0.9039
# Epoch 96/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.8815 - mse: 0.8126 - val_loss: 1.2104 - val_mse: 1.1407
# Epoch 97/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8911 - mse: 0.8228 - val_loss: 1.0936 - val_mse: 1.0256
# Epoch 98/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.8886 - mse: 0.8208 - val_loss: 1.0933 - val_mse: 1.0228
# Epoch 99/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.8578 - mse: 0.7881 - val_loss: 1.0024 - val_mse: 0.9324
# Epoch 100/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.8677 - mse: 0.7996 - val_loss: 1.1498 - val_mse: 1.0799
# Epoch 101/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8395 - mse: 0.7720 - val_loss: 0.9633 - val_mse: 0.8945
# Epoch 102/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8888 - mse: 0.8202 - val_loss: 1.1463 - val_mse: 1.0806
# Epoch 103/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8552 - mse: 0.7880 - val_loss: 1.0497 - val_mse: 0.9824
# Epoch 104/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.8377 - mse: 0.7707 - val_loss: 1.0380 - val_mse: 0.9697
# Epoch 105/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.8580 - mse: 0.7907 - val_loss: 1.0446 - val_mse: 0.9778
# Epoch 106/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.8426 - mse: 0.7755 - val_loss: 0.9185 - val_mse: 0.8533
# Epoch 107/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.8242 - mse: 0.7567 - val_loss: 1.2371 - val_mse: 1.1692
# Epoch 108/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8584 - mse: 0.7913 - val_loss: 0.9931 - val_mse: 0.9244
# Epoch 109/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8307 - mse: 0.7629 - val_loss: 0.9739 - val_mse: 0.9081
# Epoch 110/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8714 - mse: 0.8042 - val_loss: 1.1487 - val_mse: 1.0828
# Epoch 111/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8571 - mse: 0.7906 - val_loss: 1.0030 - val_mse: 0.9372
# Epoch 112/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8533 - mse: 0.7870 - val_loss: 1.0633 - val_mse: 0.9948
# Epoch 113/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8461 - mse: 0.7784 - val_loss: 1.0330 - val_mse: 0.9653
# Epoch 114/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8368 - mse: 0.7691 - val_loss: 1.1633 - val_mse: 1.0973
# Epoch 115/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8504 - mse: 0.7841 - val_loss: 0.9615 - val_mse: 0.8964
# Epoch 116/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8650 - mse: 0.7980 - val_loss: 1.1932 - val_mse: 1.1268
# Epoch 117/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.8214 - mse: 0.7535 - val_loss: 1.1565 - val_mse: 1.0905
# Epoch 118/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8499 - mse: 0.7833 - val_loss: 0.9066 - val_mse: 0.8434
# Epoch 119/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.8163 - mse: 0.7510 - val_loss: 0.9630 - val_mse: 0.8995
# Epoch 120/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.8202 - mse: 0.7550 - val_loss: 1.0072 - val_mse: 0.9434
# Epoch 121/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7796 - mse: 0.7140 - val_loss: 0.9395 - val_mse: 0.8742
# Epoch 122/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8001 - mse: 0.7340 - val_loss: 1.0420 - val_mse: 0.9752
# Epoch 123/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8448 - mse: 0.7784 - val_loss: 0.9486 - val_mse: 0.8860
# Epoch 124/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8471 - mse: 0.7835 - val_loss: 1.0805 - val_mse: 1.0159
# Epoch 125/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8167 - mse: 0.7506 - val_loss: 0.9078 - val_mse: 0.8438
# Epoch 126/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8222 - mse: 0.7578 - val_loss: 0.9545 - val_mse: 0.8925
# Epoch 127/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.7981 - mse: 0.7327 - val_loss: 1.2574 - val_mse: 1.1949
# Epoch 128/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8283 - mse: 0.7637 - val_loss: 1.1866 - val_mse: 1.1232
# Epoch 129/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8186 - mse: 0.7538 - val_loss: 1.0214 - val_mse: 0.9569
# Epoch 130/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.8286 - mse: 0.7653 - val_loss: 1.0195 - val_mse: 0.9556
# Epoch 131/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8117 - mse: 0.7488 - val_loss: 1.0079 - val_mse: 0.9442
# Epoch 132/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7910 - mse: 0.7275 - val_loss: 0.9737 - val_mse: 0.9087
# Epoch 133/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8082 - mse: 0.7447 - val_loss: 0.9360 - val_mse: 0.8742
# Epoch 134/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7636 - mse: 0.7012 - val_loss: 0.9838 - val_mse: 0.9225
# Epoch 135/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8626 - mse: 0.8012 - val_loss: 1.5578 - val_mse: 1.4923
# Epoch 136/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8815 - mse: 0.8215 - val_loss: 0.9441 - val_mse: 0.8826
# Epoch 137/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7904 - mse: 0.7290 - val_loss: 0.9696 - val_mse: 0.9078
# Epoch 138/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8252 - mse: 0.7637 - val_loss: 0.9003 - val_mse: 0.8378
# Epoch 139/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.8234 - mse: 0.7628 - val_loss: 1.0447 - val_mse: 0.9844
# Epoch 140/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7889 - mse: 0.7275 - val_loss: 0.9790 - val_mse: 0.9168
# Epoch 141/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8716 - mse: 0.8099 - val_loss: 1.0679 - val_mse: 1.0027
# Epoch 142/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.8189 - mse: 0.7568 - val_loss: 0.9669 - val_mse: 0.9077
# Epoch 143/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7941 - mse: 0.7334 - val_loss: 0.9170 - val_mse: 0.8537
# Epoch 144/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.7947 - mse: 0.7328 - val_loss: 1.0242 - val_mse: 0.9632
# Epoch 145/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.7901 - mse: 0.7302 - val_loss: 0.9821 - val_mse: 0.9239
# Epoch 146/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.7868 - mse: 0.7275 - val_loss: 0.9198 - val_mse: 0.8603
# Epoch 147/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8092 - mse: 0.7486 - val_loss: 0.9631 - val_mse: 0.9024
# Epoch 148/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.7979 - mse: 0.7375 - val_loss: 1.0079 - val_mse: 0.9478
# Epoch 149/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8156 - mse: 0.7549 - val_loss: 1.0586 - val_mse: 0.9994
# Epoch 150/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.7892 - mse: 0.7290 - val_loss: 1.0584 - val_mse: 0.9987
# Epoch 151/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7674 - mse: 0.7076 - val_loss: 1.0399 - val_mse: 0.9781
# Epoch 152/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7753 - mse: 0.7169 - val_loss: 0.9840 - val_mse: 0.9225
# Epoch 153/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8231 - mse: 0.7636 - val_loss: 1.0831 - val_mse: 1.0230
# Epoch 154/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7828 - mse: 0.7220 - val_loss: 1.0653 - val_mse: 1.0075
# Epoch 155/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7776 - mse: 0.7190 - val_loss: 0.9759 - val_mse: 0.9159
# Epoch 156/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7638 - mse: 0.7048 - val_loss: 0.9994 - val_mse: 0.9408
# Epoch 157/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7639 - mse: 0.7048 - val_loss: 1.2045 - val_mse: 1.1471
# Epoch 158/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.7604 - mse: 0.7013 - val_loss: 0.9282 - val_mse: 0.8703
# Epoch 159/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8085 - mse: 0.7508 - val_loss: 1.1018 - val_mse: 1.0437
# Epoch 160/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7745 - mse: 0.7167 - val_loss: 0.9579 - val_mse: 0.8996
# Epoch 161/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7963 - mse: 0.7386 - val_loss: 0.9997 - val_mse: 0.9418
# Epoch 162/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7642 - mse: 0.7050 - val_loss: 0.9526 - val_mse: 0.8961
# Epoch 163/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7691 - mse: 0.7117 - val_loss: 1.0243 - val_mse: 0.9663
# Epoch 164/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7920 - mse: 0.7334 - val_loss: 1.0306 - val_mse: 0.9713
# Epoch 165/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7745 - mse: 0.7151 - val_loss: 1.2376 - val_mse: 1.1782
# Epoch 166/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7871 - mse: 0.7289 - val_loss: 1.0091 - val_mse: 0.9515
# Epoch 167/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.7817 - mse: 0.7244 - val_loss: 0.9254 - val_mse: 0.8668
# Epoch 168/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7577 - mse: 0.6996 - val_loss: 1.0424 - val_mse: 0.9841
# Epoch 169/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7777 - mse: 0.7185 - val_loss: 1.0458 - val_mse: 0.9851
# Epoch 170/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7529 - mse: 0.6929 - val_loss: 0.9331 - val_mse: 0.8758
# Epoch 171/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.7611 - mse: 0.7016 - val_loss: 0.9299 - val_mse: 0.8687
# Epoch 172/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7678 - mse: 0.7080 - val_loss: 1.1879 - val_mse: 1.1278
# Epoch 173/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8000 - mse: 0.7409 - val_loss: 1.0064 - val_mse: 0.9514
# Epoch 174/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7643 - mse: 0.7066 - val_loss: 0.9303 - val_mse: 0.8722
# Epoch 175/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.7553 - mse: 0.6962 - val_loss: 1.0531 - val_mse: 0.9939
# Epoch 176/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7666 - mse: 0.7075 - val_loss: 0.9701 - val_mse: 0.9119
# Epoch 177/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7935 - mse: 0.7357 - val_loss: 1.0243 - val_mse: 0.9635
# Epoch 178/10000
# 86/86 [==============================] - 0s 6ms/step - loss: 0.7661 - mse: 0.7062 - val_loss: 0.9579 - val_mse: 0.9001
# Epoch 179/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.7806 - mse: 0.7212 - val_loss: 1.1076 - val_mse: 1.0481
# Epoch 180/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7395 - mse: 0.6802 - val_loss: 1.0700 - val_mse: 1.0101
# Epoch 181/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.7664 - mse: 0.7073 - val_loss: 0.9559 - val_mse: 0.8973
# Epoch 182/10000
# 86/86 [==============================] - 1s 6ms/step - loss: 0.7332 - mse: 0.6750 - val_loss: 0.9571 - val_mse: 0.8978
# Epoch 183/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7717 - mse: 0.7131 - val_loss: 0.9656 - val_mse: 0.9076
# Epoch 184/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.8019 - mse: 0.7444 - val_loss: 1.0388 - val_mse: 0.9812
# Epoch 185/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7521 - mse: 0.6938 - val_loss: 1.1268 - val_mse: 1.0693
# Epoch 186/10000
# 86/86 [==============================] - 1s 7ms/step - loss: 0.7759 - mse: 0.7177 - val_loss: 0.9872 - val_mse: 0.9296
# Epoch 187/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7968 - mse: 0.7388 - val_loss: 1.1669 - val_mse: 1.1075
# Epoch 188/10000
# 86/86 [==============================] - 0s 5ms/step - loss: 0.7438 - mse: 0.6850 - val_loss: 1.0335 - val_mse: 0.9758

# %%
test = pd.read_csv('./test.csv')
test = test.drop(['ID'],axis=1)
# Out:
#                                                 Smiles
# 0    O=C(C1=CSC(C2=CC=CN=C2)=N1)NC3=CC(NC4CCN(C)CC4...
# 1    N#CC1=CC(C=C2)=C(C=C1)N2C(N=C3)=NC(NC4CCCCC4)=...
# 2    N#CC(C=C1)=C(N[C@@H]2CCNC2)C=C1NC(N=C3)=NC=C3C...
# 3    N#CC(C=C1)=CC=C1NC(N=C2)=NC(NC3CC(NC(C=C)=O)CC...
# 4    N#CC(C=C1)=CC=C1NC(N=C2)=NC(NC3CC(N)CC3)=C2C(C...
# ..                                                 ...
# 108  N#CC1=CC(C=C2)=C(C=C1)N2C(N=C3)=NC(N4CCOCC4)=C...
# 109  O=C(C1=CSC(C2=CC=NC=C2)=N1)NC3=CC(NC4CCN(C(C)C...
# 110  N#Cc1ccc(Nc2ncc(cn2)c3cnn(c3)C4CCNCC4)cc1N[C@@...
# 111  O=C(C)N(CC1)CCC1N2N=CC(C3=CN=C(N4C(C=CC(C#N)=C...
# 112  N#CC(C=C1)=CC=C1NC(N=C2)=NC(NC3CNCCC3)=C2C(C=N...
#
# [113 rows x 1 columns]

# %%
test = test['Smiles'].tolist()

# Tokenize the SMILES strings
tokenizer = Tokenizer(char_level=True, filters='')
tokenizer.fit_on_texts(test)
test_sequences = tokenizer.texts_to_sequences(test)

# Padding sequences to have the same length (adjust maxlen as necessary)
maxlen = 10  # This should be set according to your data
test_padded = pad_sequences(test_sequences, maxlen=maxlen, padding='post')

# %%
y_pred = model.predict(test_padded)

# %%
submit = pd.read_csv('./sample_submission.csv')
submit['IC50_nM'] = pIC50_to_IC50(y_pred)
submit.head()
# Out:
#          ID     IC50_nM
# 0  TEST_000  131.468048
# 1  TEST_001   18.565424
# 2  TEST_002   22.130863
# 3  TEST_003    8.976595
# 4  TEST_004    8.976595

# %%
submit.to_csv('./baseline_submit.csv', index=False)
